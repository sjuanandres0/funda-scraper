# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import pandas as pd

# %%
pd.read_csv('funda_df_2.csv')
# Out:
#     property_type                  address postal_code       city  price_kk  \
# 0       apartment   Darius Milhaudstraat 2     2324 VT     Leiden    300000
# 1       apartment  Waldeck Pyrmontstraat 3     2316 PA     Leiden    375000
# 2           house           Herengracht 23     2312 LA     Leiden   1100000
# 3           house      Dwars Havenstraat 7     2312 MC     Leiden    360000
# 4           house     Van den Berghlaan 83     2132 AB  Hoofddorp   1200000
# ..            ...                      ...         ...        ...       ...
# 395         house     Willem Dreesstraat 6     2406 DP     Alphen    795000
# 396         house         Dr. Lovinklaan 6     2405 CM     Alphen    800000
# 397         house             Iepstraat 42     2404 EM     Alphen    225000
# 398         house      Zuiderkeerkring 401     2408 HT     Alphen    475000
# 399         house           Warmoezerij 22     2404 HX     Alphen    399000
#
# ...
